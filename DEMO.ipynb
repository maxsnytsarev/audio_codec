# %% [markdown]
# **Clone codec repo locally**

# %%
# !git clone https://github.com/maxsnytsarev/audio_codec.git

# %%
# %cd audio_codec

# %% [markdown]
# **Install all needed requirements**

# %%
# !pip install -r requirements.txt

# %%
from IPython.display import Audio, display
import demo
# Out:
# /Users/maximsnytsarev/anaconda3/envs/audio_codec/lib/python3.12/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %% [markdown]
# **Place here your link to the audio file**.
# It is important that audio could be downloaded via link

# %%
your_url = "https://keithito.com/LJ-Speech-Dataset/LJ025-0076.wav"

# %% [markdown]
# **We will download your audio**

# %%
wav = demo.download_wav(your_url)
display(Audio("demo_dir/demo_real.wav"))
# Out:
# --2026-05-14 18:56:47--  https://keithito.com/LJ-Speech-Dataset/LJ025-0076.wav
# Resolving keithito.com (keithito.com)... 151.101.65.195, 151.101.1.195
# Connecting to keithito.com (keithito.com)|151.101.65.195|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 370336 (362K) [audio/wav]
# Saving to: ‘demo_dir/demo_real.wav’
#
#      0K .......... .......... .......... .......... .......... 13%  184K 2s
#     50K .......... .......... .......... .......... .......... 27%  529K 1s
#    100K .......... .......... .......... .......... .......... 41%  479M 1s
#    150K .......... .......... .......... .......... .......... 55% 1.29M 0s
#    200K .......... .......... .......... ........
# Download finished
# .. .......... 69%  740K 0s
#    250K .......... .......... .......... .......... .......... 82% 3.90M 0s
#    300K .......... .......... .......... .......... .......... 96%  879K 0s
#    350K .......... .                                          100% 6.54M=0.5s
#
# 2026-05-14 18:57:01 (666 KB/s) - ‘demo_dir/demo_real.wav’ saved [370336/370336]

# %% [markdown]
# **Now we will get the reconstructed audio**

# %%
reconstructed = demo.get_reconstructed_audio(wav)
# Out:
# /Users/maximsnytsarev/anaconda3/envs/audio_codec/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# /Users/maximsnytsarev/PycharmProjects/audio_codec/demo.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(check, map_location=device)
# /Users/maximsnytsarev/PycharmProjects/audio_codec
# Saved reconstructed wav to demo_dir/demo_reconstructed.wav

# %% [markdown]
# **You can compare real audio and reconstructed**

# %%
display(Audio("demo_dir/demo_real_16k.wav")) # real audio sampled to 16kHz
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display(Audio("demo_dir/demo_reconstructed.wav")) # reconstructed audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
